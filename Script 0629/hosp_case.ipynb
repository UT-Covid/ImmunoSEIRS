# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_hosp = pd.read_csv('COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_State_Timeseries.csv')

# %%
data_hosp
# Out:
#       state        date  critical_staffing_shortage_today_yes  \
# 0        VI  2020/10/16                                     1
# 1        VT  2020/10/15                                     1
# 2        VI  2020/10/12                                     1
# 3        UT  2020/10/11                                     4
# 4        VI  2020/10/10                                     1
# ...     ...         ...                                   ...
# 45636    AZ  2020/12/28                                    39
# 45637    TN  2021/09/14                                    30
# 45638    LA  2021/09/15                                    68
# 45639    UT  2021/12/11                                     1
# 45640    VI  2021/10/11                                     1
#
#        critical_staffing_shortage_today_no  \
# 0                                        1
# 1                                       15
# 2                                        1
# 3                                       49
# 4                                        1
# ...                                    ...
# 45636                                   62
# 45637                                   79
# 45638                                  149
# 45639                                   49
# 45640                                    1
#
#        critical_staffing_shortage_today_not_reported  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  3
# 4                                                  0
# ...                                              ...
# 45636                                              3
# 45637                                             33
# 45638                                              7
# 45639                                              9
# 45640                                              0
#
#        critical_staffing_shortage_anticipated_within_week_yes  \
# 0                                                      2
# 1                                                      1
# 2                                                      2
# 3                                                      7
# 4                                                      2
# ...                                                  ...
# 45636                                                 41
# 45637                                                 48
# 45638                                                 67
# 45639                                                  1
# 45640                                                  1
#
#        critical_staffing_shortage_anticipated_within_week_no  \
# 0                                                      0
# 1                                                     15
# 2                                                      0
# 3                                                     46
# 4                                                      0
# ...                                                  ...
# 45636                                                 60
# 45637                                                 61
# 45638                                                150
# 45639                                                 49
# 45640                                                  1
#
#        critical_staffing_shortage_anticipated_within_week_not_reported  \
# 0                                                      0
# 1                                                      1
# 2                                                      0
# 3                                                      3
# 4                                                      0
# ...                                                  ...
# 45636                                                  3
# 45637                                                 33
# 45638                                                  7
# 45639                                                  9
# 45640                                                  0
#
#        hospital_onset_covid  hospital_onset_covid_coverage  ...  \
# 0                       0.0                              2  ...
# 1                       0.0                             16  ...
# 2                       0.0                              2  ...
# 3                       4.0                             54  ...
# 4                       0.0                              2  ...
# ...                     ...                            ...  ...
# 45636                  69.0                            101  ...
# 45637                  40.0                            109  ...
# 45638                   6.0                            217  ...
# 45639                   4.0                             58  ...
# 45640                   0.0                              2  ...
#
#        previous_day_admission_pediatric_covid_confirmed_5_11  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 45636                                                NaN
# 45637                                                NaN
# 45638                                                NaN
# 45639                                                NaN
# 45640                                                NaN
#
#        previous_day_admission_pediatric_covid_confirmed_5_11_coverage  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 45636                                                  0
# 45637                                                  0
# 45638                                                  0
# 45639                                                  0
# 45640                                                  0
#
#        previous_day_admission_pediatric_covid_confirmed_unknown  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 45636                                                NaN
# 45637                                                NaN
# 45638                                                NaN
# 45639                                                NaN
# 45640                                                NaN
#
#        previous_day_admission_pediatric_covid_confirmed_unknown_coverage  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 45636                                                  0
# 45637                                                  0
# 45638                                                  0
# 45639                                                  0
# 45640                                                  0
#
#        staffed_icu_pediatric_patients_confirmed_covid  \
# 0                                                 NaN
# 1                                                 0.0
# 2                                                 NaN
# 3                                                 0.0
# 4                                                 NaN
# ...                                               ...
# 45636                                             NaN
# 45637                                             NaN
# 45638                                             NaN
# 45639                                             NaN
# 45640                                             NaN
#
#        staffed_icu_pediatric_patients_confirmed_covid_coverage  \
# 0                                                      0
# 1                                                      1
# 2                                                      0
# 3                                                     43
# 4                                                      0
# ...                                                  ...
# 45636                                                  0
# 45637                                                  0
# 45638                                                  0
# 45639                                                  0
# 45640                                                  0
#
#        staffed_pediatric_icu_bed_occupancy  \
# 0                                      NaN
# 1                                     18.0
# 2                                      NaN
# 3                                    219.0
# 4                                      NaN
# ...                                    ...
# 45636                                174.0
# 45637                                  0.0
# 45638                                 11.0
# 45639                                257.0
# 45640                                  0.0
#
#        staffed_pediatric_icu_bed_occupancy_coverage  \
# 0                                                 0
# 1                                                 1
# 2                                                 0
# 3                                                44
# 4                                                 0
# ...                                             ...
# 45636                                           101
# 45637                                            13
# 45638                                             5
# 45639                                            58
# 45640                                             2
#
#        total_staffed_pediatric_icu_beds  \
# 0                                   NaN
# 1                                  33.0
# 2                                   NaN
# 3                                 416.0
# 4                                   NaN
# ...                                 ...
# 45636                             296.0
# 45637                               1.0
# 45638                              11.0
# 45639                             405.0
# 45640                               6.0
#
#        total_staffed_pediatric_icu_beds_coverage
# 0                                              0
# 1                                              1
# 2                                              0
# 3                                             41
# 4                                              0
# ...                                          ...
# 45636                                        101
# 45637                                         13
# 45638                                          5
# 45639                                         58
# 45640                                          2
#
# [45641 rows x 135 columns]

# %%
data_date3 = pd.read_excel('date-fit.xlsx')
date_series = data_date3['date'].squeeze()
date_series_str = date_series.dt.strftime('%Y/%m/%d')
date_series_str3 = date_series.dt.strftime('%Y-%m-%d')
date_series_str2 = date_series.dt.strftime('%m/%d/%Y')

# %%
def get_info2(XX, state, df2, b):
    listo = list(date_series_str)
    for x in listo:
        df = df2[df2['date'] == XX] 
        df = df[df['state'] == state]
        a = df[b]
        if df.size == 0:
            return float('nan')
        else:
            return a.squeeze()

# %%
get_info2('2022/03/09', 'US', data_hosp, 'previous_day_admission_adult_covid_confirmed_18-19')
# Out:
# nan

# %%
import datetime as dt
hosp_data = pd.DataFrame(columns = ['date', 'state', '0-4', '5-11', '12-18', '19-49', '50-64', '65+', 'tot'])
   
cov_65 = 0
cov_50_64 = 0
cov_19_49 = 0
cov_12_18 = 0
cov_tot = 0
print('FL')
i = 0
for date in date_series_str:
    cov_65 = get_info2(date, 'FL', data_hosp, 'previous_day_admission_adult_covid_confirmed_70-79') + 0.5*get_info2(date, 'FL', data_hosp, 'previous_day_admission_adult_covid_confirmed_60-69') + get_info2(date, 'FL', data_hosp, 'previous_day_admission_adult_covid_confirmed_80+')
    cov_50_64 = get_info2(date, 'FL', data_hosp, 'previous_day_admission_adult_covid_confirmed_50-59') + 0.5*get_info2(date, 'FL', data_hosp, 'previous_day_admission_adult_covid_confirmed_60-69')
    cov_19_49 = get_info2(date, 'FL', data_hosp, 'previous_day_admission_adult_covid_confirmed_18-19') + get_info2(date, 'FL', data_hosp, 'previous_day_admission_adult_covid_confirmed_20-29') + get_info2(date, 'FL', data_hosp, 'previous_day_admission_adult_covid_confirmed_30-39') + get_info2(date, 'FL', data_hosp, 'previous_day_admission_adult_covid_confirmed_40-49')    
    cov_tot = cov_65 + cov_50_64 + cov_19_49
    hosp_data = hosp_data.append({'date' : date, 'state' : 'FL', '0-4' : 0, '5-11' : 0, '12-18' : 0, '19-49' : cov_19_49, '50-64' : cov_50_64, '65+' : cov_65, 'tot': cov_tot}, 
            ignore_index = True)
    i = i+1
# Out:
# FL

# %%
hosp_data
# Out:
#            date state 0-4 5-11 12-18  19-49  50-64    65+    tot
# 0    2022/02/21    FL   0    0     0   64.0   73.5  207.5  345.0
# 1    2022/02/22    FL   0    0     0   83.0   90.0  264.0  437.0
# 2    2022/02/23    FL   0    0     0   58.0   78.0  225.0  361.0
# 3    2022/02/24    FL   0    0     0   71.0   77.5  231.5  380.0
# 4    2022/02/25    FL   0    0     0   62.0   85.0  204.0  351.0
# ..          ...   ...  ..  ...   ...    ...    ...    ...    ...
# 124  2022/06/25    FL   0    0     0  128.0  130.0  375.0  633.0
# 125  2022/06/26    FL   0    0     0   91.0  114.0  333.0  538.0
# 126  2022/06/27    FL   0    0     0  108.0  115.0  333.0  556.0
# 127  2022/06/28    FL   0    0     0  117.0  134.5  401.5  653.0
# 128  2022/06/29    FL   0    0     0  117.0  134.5  401.5  653.0
#
# [129 rows x 9 columns]

# %%
state_abv= pd.read_csv('states.csv')

# %%
def get_state(state, df2):
    df = df2[df2['Abbreviation'] == state]
    a = df['State']
    if df.size == 0:
        return float('nan')
    else:
        return a.squeeze()

# %%
get_state('UT' , state_abv)
# Out:
# 'Utah'

# %%
State_cases = pd.read_csv('us-states.csv')

# %%
def get_fit_data(state):
    fit_data = pd.DataFrame(columns = ['date', 'state', 'death', 'case', 'hosp'])
    death = 0
    case = 0
    cov_tot = 0
    i = 0
    state_comp = get_state(state, state_abv) 
    for date in date_series_str:
        death = get_info2(date_series_str3[i], state_comp, State_cases, 'deaths')
        case = get_info2(date_series_str3[i], state_comp, State_cases, 'cases')
        cov_65 = get_info2(date_series_str[i], state, data_hosp, 'previous_day_admission_adult_covid_confirmed_70-79') + 0.5*get_info2(date_series_str[i], state, data_hosp, 'previous_day_admission_adult_covid_confirmed_60-69') + get_info2(date_series_str[i], state, data_hosp, 'previous_day_admission_adult_covid_confirmed_80+')
        cov_50_64 = get_info2(date_series_str[i], state, data_hosp, 'previous_day_admission_adult_covid_confirmed_50-59') + 0.5*get_info2(date_series_str[i], state, data_hosp, 'previous_day_admission_adult_covid_confirmed_60-69')
        cov_19_49 = get_info2(date_series_str[i], state, data_hosp, 'previous_day_admission_adult_covid_confirmed_18-19') + get_info2(date_series_str[i], state, data_hosp, 'previous_day_admission_adult_covid_confirmed_20-29') + get_info2(date_series_str[i], state, data_hosp, 'previous_day_admission_adult_covid_confirmed_30-39') + get_info2(date_series_str[i], state, data_hosp, 'previous_day_admission_adult_covid_confirmed_40-49')    
        cov_tot = cov_65 + cov_50_64 + cov_19_49

        fit_data = fit_data.append({'date' : date, 'state' : state, 'death' : death, 'case' : case, 'hosp' : cov_tot}, 
                ignore_index = True)
        i = i+1
    return fit_data

# %%
x = 'AL'
fit_data = get_fit_data(x)

# %%
fit_data
# Out:
#            date state  death     case   hosp
# 0    2022/02/21    AL  17933  1273484   95.0
# 1    2022/02/22    AL  17938  1274123  105.0
# 2    2022/02/23    AL  18007  1275355  106.0
# 3    2022/02/24    AL  18102  1276580   79.0
# 4    2022/02/25    AL  18186  1277837  107.0
# ..          ...   ...    ...      ...    ...
# 124  2022/06/25    AL  19729  1346268   86.0
# 125  2022/06/26    AL  19729  1346268   72.0
# 126  2022/06/27    AL  19734  1350735   87.0
# 127  2022/06/28    AL  19739  1352915  108.0
# 128  2022/06/29    AL    NaN      NaN  108.0
#
# [129 rows x 5 columns]

# %%
state_list = pd.read_excel('FIPState.xlsx')

# %%
state_series = state_list['st'].squeeze()

# %%
state_series
# Out:
# 0     AL
# 1     AK
# 2     AZ
# 3     AR
# 4     CA
# 5     CO
# 6     CT
# 7     DE
# 8     FL
# 9     GA
# 10    HI
# 11    ID
# 12    IL
# 13    IN
# 14    IA
# 15    KS
# 16    KY
# 17    LA
# 18    ME
# 19    MD
# 20    MA
# 21    MI
# 22    MN
# 23    MS
# 24    MO
# 25    MT
# 26    NE
# 27    NV
# 28    NH
# 29    NJ
# 30    NM
# 31    NY
# 32    NC
# 33    ND
# 34    OH
# 35    OK
# 36    OR
# 37    PA
# 38    RI
# 39    SC
# 40    SD
# 41    TN
# 42    TX
# 43    UT
# 44    VT
# 45    VA
# 46    WA
# 47    WV
# 48    WI
# 49    WY
# Name: st, dtype: object

# %%
listo = list(state_series)
for x in listo:
    x = x.strip()
    fit_data = get_fit_data(x)
    y = "fit_data/" + x + ".csv"
    fit_data.to_csv(y)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_62108/3016679546.py in <module>
#       4     fit_data = get_fit_data(x)
#       5     y = "fit_data/" + x + ".csv"
# ----> 6     fit_data.to_csv(y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fit_data/AL.csv'

# %%
    x = 'WV'
    fit_data = get_fit_data(x)
    y = "fit_data/" + x + ".csv"
    fit_data.to_csv(y)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_62108/1077501943.py in <module>
#       2 fit_data = get_fit_data(x)
#       3 y = "fit_data/" + x + ".csv"
# ----> 4 fit_data.to_csv(y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fit_data/WV.csv'

# %%
USA_cases = pd.read_csv('us.csv')

# %%
def get_info3(XX, df2, b):
    listo = list(date_series_str)
    for x in listo:
        df = df2[df2['date'] == XX] 
        a = df[b]
        if df.size == 0:
            return float('nan')
        else:
            return a.squeeze()

# %%
fit_us_data = pd.DataFrame(columns = ['date', 'state', 'death', 'case', 'hosp'])
death = 0
case = 0
cov_tot = 0
i = 0
state = 'US'
listo = list(state_series)
state_comp = get_state(state, state_abv) 
for date in date_series_str:
    death = get_info3(date_series_str3[i], USA_cases, 'deaths')
    case = get_info3(date_series_str3[i],  USA_cases, 'cases')
    listo = list(state_series)
    hospis = 0
    for x in listo:
        x = x.strip()
        cov_65 = get_info2(date_series_str[i], x, data_hosp, 'previous_day_admission_adult_covid_confirmed_70-79') + 0.5*get_info2(date_series_str[i], x, data_hosp, 'previous_day_admission_adult_covid_confirmed_60-69') + get_info2(date_series_str[i], x, data_hosp, 'previous_day_admission_adult_covid_confirmed_80+')
        cov_50_64 = get_info2(date_series_str[i], x, data_hosp, 'previous_day_admission_adult_covid_confirmed_50-59') + 0.5*get_info2(date_series_str[i], x, data_hosp, 'previous_day_admission_adult_covid_confirmed_60-69')
        cov_19_49 = get_info2(date_series_str[i], x, data_hosp, 'previous_day_admission_adult_covid_confirmed_18-19') + get_info2(date_series_str[i], x, data_hosp, 'previous_day_admission_adult_covid_confirmed_20-29') + get_info2(date_series_str[i], x, data_hosp, 'previous_day_admission_adult_covid_confirmed_30-39') + get_info2(date_series_str[i], x, data_hosp, 'previous_day_admission_adult_covid_confirmed_40-49')    
        cov_tot = cov_65 + cov_50_64 + cov_19_49
        hospis = hospis + cov_tot
    fit_us_data = fit_us_data.append({'date' : date, 'state' : state, 'death' : death, 'case' : case, 'hosp' : hospis}, 
            ignore_index = True)
    i = i+1

# %%
fit_us_data.to_csv('fit_data_us.csv')

# %%
fit_us_data
# Out:
#            date state    death      case    hosp
# 0    2022/02/21    US   934654  78433652  4399.0
# 1    2022/02/22    US   937380  78556769  5336.0
# 2    2022/02/23    US   940404  78641313  5182.0
# 3    2022/02/24    US   943312  78714719  4727.0
# 4    2022/02/25    US   946121  78800705  4490.0
# ..          ...   ...      ...       ...     ...
# 124  2022/06/25    US  1012480  86881533  4890.0
# 125  2022/06/26    US  1012486  86899773  4397.0
# 126  2022/06/27    US  1012765  87031752  4419.0
# 127  2022/06/28    US  1013306  87154263  5031.0
# 128  2022/06/29    US      NaN       NaN  5001.0
#
# [129 rows x 5 columns]
